# %% [markdown]
# ## **⚡ ANTIGRAVITY AGENT STUDIO (Kaggle Dual-GPU & Colab 1-Click)**
# An autonomous AI coding and development agent with **full shell execution, file system management, and automatic project builder capabilities**!
#
# Supported on **Kaggle (Dual GPU T4)** and **Google Colab** • Powered by **Qwen2.5-Coder-7B-Instruct** • 100% Free & Zero API Keys Needed!
#
# [GitHub Repository](https://github.com/OddBoyXD/ai-faceswapper-pro)
#
# <br>
#
# ---
#
# <br>
#
# #### **Highlights & Capabilities**
# * 🤖 **Autonomous Tool Execution**: Automatically writes code, creates directories, runs terminal commands, and fixes errors
# * 💻 **Full-Stack Development**: Build Python apps, REST APIs, scripts, HTML5 web games, or automated bots
# * 📂 **Live Workspace File Explorer**: Browse, inspect, and download any generated code or output directly in your browser
# * 🚀 **Kaggle Dual-GPU & Colab Free**: Runs 100% free with no disconnects

# %% [markdown]
# ### **1. Setup Environment & Install Dependencies**
# Run this cell to setup the environment and install AI dependencies.

# %%
# @title Install Transformers, BitsAndBytes & Gradio (1-Click)
import os
import sys
from IPython.display import clear_output

work_dir = "/kaggle/working" if os.path.exists("/kaggle") else "/content"
# %cd {work_dir}

print("📦 Step 1/3: Cloning Antigravity Studio repository...")
repo_path = os.path.join(work_dir, "ai-faceswapper-pro")
if not os.path.exists(repo_path):
  # !git clone https://github.com/OddBoyXD/ai-faceswapper-pro.git {repo_path}
else:
  # %cd {repo_path}
  # !git pull

# %cd {repo_path}

print("🤖 Step 2/3: Installing Transformers, BitsAndBytes & Gradio...")
# !pip install -q --upgrade pip
# !pip install -q torch transformers accelerate bitsandbytes gradio

clear_output()
print("=" * 60)
print("✅ Setup Complete! Antigravity Agent Studio is 100% Ready.")
print("👉 Run Step 2 below to launch your Autonomous Agent CLI!")
print("=" * 60)

# %% [markdown]
# ### **2. Launch Antigravity Agent Studio (Click Public Link)**
# Run this cell to start the server and click the public `.gradio.live` link.

# %%
# @title **Launch Antigravity Agent WebUI**
from IPython.display import clear_output
import os

work_dir = "/kaggle/working" if os.path.exists("/kaggle") else "/content"
repo_path = os.path.join(work_dir, "ai-faceswapper-pro")
# %cd {repo_path}

print("🌐 Starting Antigravity Agent CLI WebUI...")
# !python antigravity_agent_studio.py
