# %% [markdown]
# ## **⚡ ANTIGRAVITY AGENT STUDIO (Claude Code & Gemini CLI Edition)**
# An autonomous AI coding and development agent with **full shell execution, file system management, and automatic project builder capabilities**!
#
# Powered by **Qwen2.5-Coder-7B-Instruct** • 100% Free on Colab Free T4 GPU • Zero API Keys Needed!
#
# [GitHub Repository](https://github.com/OddBoyXD/ai-faceswapper-pro)
#
# <br>
#
# ---
#
# <br>
#
# #### **Highlights & Capabilities**
# * 🤖 **Autonomous Tool Execution**: Automatically writes code, creates directories, runs terminal commands, and fixes errors
# * ⛏️ **1-Click Minecraft .JAR Builder**: Generate full Fabric/Forge mods and compile them into `.jar` files
# * 💻 **Full-Stack Development**: Build Python apps, REST APIs, scripts, HTML5 web games, or automated bots
# * 📂 **Live Workspace File Explorer**: Browse, inspect, and download any generated code or `.jar` mod directly in your browser
# * 💾 **Auto-Save to Google Drive**: Automatically syncs outputs to `/MyDrive/Antigravity_Mods/`

# %% [markdown]
# ### **1. Setup Environment & Mount Google Drive**
# Run these cells to install Java 17 and AI dependencies.

# %%
# @title Mount Google Drive (Optional)
# @markdown 💾 Run this to save your generated `.jar` mod files and projects directly into your Google Drive.
from google.colab import drive
import os

try:
  drive.mount("/content/drive")
  os.makedirs("/content/drive/MyDrive/Antigravity_Mods", exist_ok=True)
  print("✅ Google Drive connected! Saved folder: /content/drive/MyDrive/Antigravity_Mods")
except Exception as e:
  print("⚠️ Google Drive not mounted (optional step skipped)")

# %%
# @title Install Java 17, Transformers, BitsAndBytes & Gradio
# @markdown ⚙️ Sets up Java compilation tools and AI model packages.
import os
import sys
from IPython.display import clear_output

# %cd /content
print("📦 Step 1/3: Cloning Antigravity Studio repository...")
if not os.path.exists("/content/ai-faceswapper-pro"):
  # !git clone https://github.com/OddBoyXD/ai-faceswapper-pro.git /content/ai-faceswapper-pro
else:
  # %cd /content/ai-faceswapper-pro
  # !git pull

# %cd /content/ai-faceswapper-pro

print("☕ Step 2/3: Installing OpenJDK 17 & Build Tools...")
# !apt-get update -qq && apt-get install -y -qq openjdk-17-jdk gradle ffmpeg

print("🤖 Step 3/3: Installing Transformers, BitsAndBytes & Gradio...")
# !pip install -q --upgrade pip
# !pip install -q torch transformers accelerate bitsandbytes gradio

clear_output()
print("=" * 60)
print("✅ Setup Complete! Antigravity Agent Studio is Ready.")
print("👉 Run Step 2 below to launch your Autonomous Agent CLI!")
print("=" * 60)

# %% [markdown]
# ### **2. Launch Antigravity Agent Studio (Click Public Link)**
# Run this cell to start the server and click the public `.gradio.live` link.

# %%
# @title **Launch Antigravity Agent WebUI**
from IPython.display import clear_output
import os

# %cd /content/ai-faceswapper-pro

print("🌐 Starting Antigravity Agent CLI WebUI...")
# !python antigravity_agent_studio.py
