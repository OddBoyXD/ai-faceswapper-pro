# %% [markdown]
# ## **⛏️ AI Minecraft Mod Maker & Studio (Qwen2.5-Coder Edition)**
# Generate complete, working **Minecraft Java Edition Mods in `.jar` format** directly from your browser!
#
# Powered by **Qwen2.5-Coder-7B-Instruct** (The #1 Open-Source AI Coding Model) • 100% Free on Colab Free T4 GPU • Zero API Keys Needed!
#
# [GitHub Repository](https://github.com/OddBoyXD/ai-faceswapper-pro)
#
# <br>
#
# ---
#
# <br>
#
# #### **Highlights & Capabilities**
# * ⚔️ **Custom Weapons & Tools**: Custom attack damage, attack speed, durability, and special effects (Lightning on hit, Fire Aspect, Explosions)
# * 🛡️ **Custom Armor Sets**: Full armor sets with potion effects (Speed II, Night Vision, Resistance)
# * 💬 **Interactive AI Chatbot**: Chat with Qwen2.5-Coder to code custom mechanics, recipes, and event handlers in English or Hindi
# * 📦 **1-Click `.JAR` Builder**: Automatically packages Java classes, `fabric.mod.json`, assets, and recipes into a downloadable `.jar` file
# * 💾 **Auto-Save to Google Drive**: All built `.jar` files are automatically saved to `/MyDrive/Minecraft_Mods/`

# %% [markdown]
# ### **1. Setup Environment & Mount Google Drive**
# Run these cells to install Java 17 and Python AI packages.

# %%
# @title Mount Google Drive (Optional)
# @markdown 💾 Run this to save your generated `.jar` mod files directly into your Google Drive.
from google.colab import drive
import os

try:
  drive.mount("/content/drive")
  os.makedirs("/content/drive/MyDrive/Minecraft_Mods", exist_ok=True)
  print("✅ Google Drive connected! Saved mods folder: /content/drive/MyDrive/Minecraft_Mods")
except Exception as e:
  print("⚠️ Google Drive not mounted (optional step skipped)")

# %%
# @title Install OpenJDK 17, Transformers, BitsAndBytes & Gradio
# @markdown ⚙️ Sets up Java compilation environment and AI dependencies.
import os
import sys
from IPython.display import clear_output

# %cd /content
print("📦 Step 1/3: Cloning Minecraft Mod Studio repository...")
if not os.path.exists("/content/ai-faceswapper-pro"):
  # !git clone https://github.com/OddBoyXD/ai-faceswapper-pro.git /content/ai-faceswapper-pro
else:
  # %cd /content/ai-faceswapper-pro
  # !git pull

# %cd /content/ai-faceswapper-pro

print("☕ Step 2/3: Installing OpenJDK 17 & Java Tools...")
# !apt-get update -qq && apt-get install -y -qq openjdk-17-jdk gradle

print("🤖 Step 3/3: Installing Transformers, BitsAndBytes & Gradio...")
# !pip install -q --upgrade pip
# !pip install -q torch transformers accelerate bitsandbytes gradio

clear_output()
print("=" * 60)
print("✅ Setup Complete! Qwen2.5-Coder Minecraft Studio is Ready.")
print("👉 Run Step 2 below to launch your Mod Maker WebUI!")
print("=" * 60)

# %% [markdown]
# ### **2. Launch AI Minecraft Mod Studio (Click Public Link)**
# Run this cell to start the server and click the public `.gradio.live` link.

# %%
# @title **Launch AI Minecraft Mod Studio WebUI**
from IPython.display import clear_output
import os

# %cd /content/ai-faceswapper-pro

print("🌐 Starting Minecraft Mod Maker WebUI...")
# !python minecraft_mod_studio.py
