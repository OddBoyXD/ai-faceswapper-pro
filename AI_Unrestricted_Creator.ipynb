# %% [markdown]
# ## **⚡ AI Unrestricted Creator 4K • Text-to-Image & Smart Photo Editor**
# Generate 4K photorealistic images with **zero censorship filters** and edit existing photos with plain text instructions!
#
# Supported on **Kaggle (Dual GPU T4)** and **Google Colab** • 100% Free & Unlimited!
#
# [GitHub Repository](https://github.com/OddBoyXD/ai-faceswapper-pro)
#
# <br>
#
# ---
#
# <br>
#
# #### **Highlights & Capabilities**
# * 🪄 **4K Text-to-Image Studio**: Generate anything without arbitrary filters or blocked prompts
# * 🎨 **Smart Instruction Photo Editor**: Upload any image and instruct: *'Change background to Tokyo'*, *'Add sunglasses'*, *'Change clothes to leather jacket'*
# * 🚀 **Kaggle Dual-GPU & Colab Free**: Runs 100% free with no disconnects

# %% [markdown]
# ### **1. Setup Environment & Install Dependencies**
# Run this cell to setup the environment and install diffusion packages (1-Click, Zero API Keys Needed).

# %%
# @title Install AI Image Diffusion & Photo Editing Stack
import os
import sys
from IPython.display import clear_output

work_dir = "/kaggle/working" if os.path.exists("/kaggle") else "/content"
# %cd {work_dir}

print("📦 Step 1/3: Cloning Unrestricted Creator repository...")
repo_path = os.path.join(work_dir, "ai-faceswapper-pro")
if not os.path.exists(repo_path):
  # !git clone https://github.com/OddBoyXD/ai-faceswapper-pro.git {repo_path}
else:
  # %cd {repo_path}
  # !git pull

# %cd {repo_path}

print("⚡ Step 2/3: Installing PyTorch, Diffusers & Gradio...")
# !pip install -q --upgrade pip
# !pip install -q diffusers transformers accelerate sentencepiece protobuf gradio Pillow torch torchvision

clear_output()
print("=" * 60)
print("✅ Setup Complete! Unrestricted Creator is 100% Ready.")
print("👉 Run Step 2 below to launch your WebUI!")
print("=" * 60)

# %% [markdown]
# ### **2. Launch Unrestricted Creator WebUI (Click Public Link)**
# Run this cell to start the server and click the public `.gradio.live` link.

# %%
# @title **Launch Unrestricted Creator 4K WebUI**
from IPython.display import clear_output
import os

work_dir = "/kaggle/working" if os.path.exists("/kaggle") else "/content"
repo_path = os.path.join(work_dir, "ai-faceswapper-pro")
# %cd {repo_path}

print("🌐 Starting Unrestricted Creator WebUI...")
# !python uncensored_creator_studio.py
