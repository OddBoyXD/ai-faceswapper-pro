# %% [markdown]
# ## **⚡ AI YouTube Video Creator • Zero API Key Edition**
# An All-in-One Automated Video Generator: **100% Free, Zero API Keys, Zero Pexels Keys, Zero OpenAI Keys**. Generates **AI Script + Hindi/English Voiceover + 4K Scene Visuals + Pan/Zoom Motion** and exports finished 1080p MP4 videos!
#
# [GitHub Repository](https://github.com/OddBoyXD/ai-faceswapper-pro) — [Ultra Face Swapper](https://colab.research.google.com/github/OddBoyXD/ai-faceswapper-pro/blob/main/AI_FaceSwapper_Ultra.ipynb)
#
# <br>
#
# ---
#
# <br>
#
# #### **Highlights & 5 Simple Options**
# * 1️⃣ **Video Subject / Topic**: Type any topic (e.g. *"5 Facts About the Ocean"*)
# * 2️⃣ **Voice & Language**: Hindi (Madhur / Swara), English (Deep Movie Narrator), Bengali, Urdu
# * 3️⃣ **Video Format**: 9:16 (YouTube Shorts / Reels) & 16:9 (Standard YouTube)
# * 4️⃣ **Number of Scenes**: Choose 2 to 6 scenes
# * 5️⃣ **Caption Style**: Viral Yellow/White (MrBeast) or Neon Green
# * 🚀 **Zero API Key Needed**: Runs 100% self-contained on Google Colab free T4 GPU

# %% [markdown]
# ### **1. Install Video Studio & Pre-Download Models**
# Run these cells to mount Google Drive (optional) and install all required video/audio libraries.

# %%
# @title Mount Google Drive (Optional)
# @markdown 💾 Run this to mount Google Drive so your finished videos are saved permanently.
from google.colab import drive
import os

try:
  drive.mount("/content/drive")
  os.makedirs("/content/drive/MyDrive/YouTube_Auto_Videos", exist_ok=True)
  print("✅ Google Drive connected! Saved videos folder: /content/drive/MyDrive/YouTube_Auto_Videos")
except Exception as e:
  print("⚠️ Google Drive not mounted (optional step skipped)")

# %%
# @title Setup Runtime Environment & Pre-Download Models (Zero API Keys)
# @markdown ⚙️ Installs FFmpeg, Edge-TTS, Diffusers, Transformers, and pre-caches the 4K AI model.
import os
import sys
from IPython.display import clear_output

# %cd /content
print("📦 Step 1/3: Getting latest AI YouTube Video Creator code...")
if not os.path.exists("/content/ai-faceswapper-pro"):
  # !git clone https://github.com/OddBoyXD/ai-faceswapper-pro.git /content/ai-faceswapper-pro
else:
  # %cd /content/ai-faceswapper-pro
  # !git pull

# %cd /content/ai-faceswapper-pro

print("⚡ Step 2/3: Installing FFmpeg, Edge-TTS, and video libraries...")
# !apt-get update -qq && apt-get install -y -qq ffmpeg libgl1-mesa-glx fonts-noto-cjk fonts-noto-extra
# !pip install -q --upgrade pip
# !pip install -q edge-tts diffusers transformers accelerate safetensors opencv-python-headless gradio
# !npm install -g -q localtunnel &> /dev/null

print("📥 Step 3/3: Pre-Downloading Visual Scene Generator Model...")
# !python preload_models.py

clear_output()
print("=" * 60)
print("✅ Setup Complete! AI YouTube Creator is 100% Ready (Zero API Key Needed).")
print("👉 Now run Step 2 below to instantly launch your studio!")
print("=" * 60)

# %% [markdown]
# ### **2. Start AI YouTube Creator Studio (Instant Link)**
# Run this cell to launch your WebUI and click your free public link.

# %%
# @title **Start Video Studio (Instant Gradio Link)**
# @markdown ### Choose a sharing method:
from IPython.display import clear_output
import os

method = "gradio"  # @param ["gradio", "localtunnel", "ngrok"]
ngrok_token = ""   # @param {type:"string"}

# %cd /content/ai-faceswapper-pro

# Verify GPU
try:
  import torch
  if torch.cuda.is_available():
    print(f"🚀 GPU Active: {torch.cuda.get_device_name(0)}")
  else:
    print("⚠️ Running on CPU. For maximum rendering speed, go to Runtime -> Change runtime type -> T4 GPU")
except Exception:
  pass

match method:
  case "gradio":
    # !python auto_youtube_studio.py
  case "localtunnel":
    # !echo Password IP: $(curl --silent https://ipv4.icanhazip.com)
    # !echo
    # !lt --port 7860 & python auto_youtube_studio.py
  case "ngrok":
    if not ngrok_token.strip():
      print("❌ Please enter your Ngrok token: https://dashboard.ngrok.com/get-started/your-authtoken")
    else:
      import ngrok
      ngrok.kill()
      listener = ngrok.forward(7860, authtoken=ngrok_token)
      print(f"Ngrok URL: {listener.url()}")
      # !python auto_youtube_studio.py
