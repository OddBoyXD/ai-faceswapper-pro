# %% [markdown]
# ## **⚡ FLUX.2 [dev] Studio (Kaggle Dual-GPU & Colab 1-Click)**
# The official Black Forest Labs **FLUX.2 [dev]** image generator running on **Kaggle (Dual T4 GPUs - 30 Hrs/Week Free)** and **Google Colab**!
#
# Exact replica of [Hugging Face: black-forest-labs/FLUX.2-dev](https://huggingface.co/spaces/black-forest-labs/FLUX.2-dev) • **100% Free & Zero Login / Zero Tokens Needed!**
#
# [GitHub Repository](https://github.com/OddBoyXD/ai-faceswapper-pro)
#
# <br>
#
# ---
#
# <br>
#
# #### **Highlights & Capabilities**
# * 🚀 **Kaggle Dual-GPU & Colab Supported**: Runs 100% free with no disconnects
# * 🖼️ **Multi-Reference Image Input**: Upload reference images for style, character & object consistency
# * ✨ **Built-in Local AI Prompt Upsampler**: Automatically refines your prompt with cinematic descriptors
# * ⚙️ **Exact Official UI**: Prompt box, Multi-image Gallery, Advanced Settings (Width, Height, Seed, Guidance Scale, Steps)
# * 🌐 **Public Gradio Link**: Access your private studio from any PC, Mac, Android, or iOS device

# %% [markdown]
# ### **1. Setup Environment & Install Dependencies**
# Run this cell to setup the environment and install diffusion libraries (1-Click, Zero API Keys Needed).

# %%
# @title Install FLUX.2 Dependencies (1-Click, Zero Token / Zero Login)
import os
import sys
from IPython.display import clear_output

work_dir = "/kaggle/working" if os.path.exists("/kaggle") else "/content"
# %cd {work_dir}

print("📦 Step 1/2: Cloning FLUX.2 Studio repository...")
repo_path = os.path.join(work_dir, "ai-faceswapper-pro")
if not os.path.exists(repo_path):
  # !git clone https://github.com/OddBoyXD/ai-faceswapper-pro.git {repo_path}
else:
  # %cd {repo_path}
  # !git pull

# %cd {repo_path}

print("⚡ Step 2/2: Installing PyTorch & Diffusers stack...")
# !pip install -q --upgrade pip
# !pip install -q diffusers transformers accelerate sentencepiece protobuf torchvision gradio

clear_output()
print("=" * 60)
print("✅ Setup Complete! FLUX.2 [dev] Studio is 100% Ready.")
print("👉 Run Step 2 below to launch your FLUX.2 WebUI!")
print("=" * 60)

# %% [markdown]
# ### **2. Launch FLUX.2 [dev] WebUI (Click Public Link)**
# Run this cell to start the server and click the public `.gradio.live` link.

# %%
# @title **Launch FLUX.2 [dev] WebUI**
from IPython.display import clear_output
import os

work_dir = "/kaggle/working" if os.path.exists("/kaggle") else "/content"
repo_path = os.path.join(work_dir, "ai-faceswapper-pro")
# %cd {repo_path}

print("🌐 Starting FLUX.2 [dev] WebUI...")
# !python flux2_dev_studio.py
