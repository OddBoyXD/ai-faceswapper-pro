# %% [markdown]
# ## **⚡ FLUX.2 / FLUX.1 [dev] Studio (Official UI Replica)**
# The official Black Forest Labs **FLUX.2 / FLUX.1 [dev]** image generator running on Google Colab GPU!
#
# Exact replica of the [Hugging Face Space](https://huggingface.co/spaces/black-forest-labs/FLUX.1-dev) • 12B–32B Rectified Flow Transformer • 100% Free on Colab GPU!
#
# [GitHub Repository](https://github.com/OddBoyXD/ai-faceswapper-pro)
#
# <br>
#
# ---
#
# <br>
#
# #### **Highlights & Capabilities**
# * 🎨 **Ultra-Photorealistic Typography & Hands**: Flawless text rendering and hyper-realistic anatomy
# * ⚙️ **Exact Official UI**: Prompt box, instant Run, Advanced Settings (Width, Height, Seed, Guidance Scale, Steps)
# * 💾 **Auto-Save to Google Drive**: Automatically saves high-res PNG outputs to `/MyDrive/FLUX_Images/`
# * 🌐 **Public Gradio Link**: Access your private studio from any PC, Mac, Android, or iOS device

# %% [markdown]
# ### **1. Setup Environment & Mount Google Drive**
# Run these cells to mount Google Drive and install the FLUX dependencies.

# %%
# @title Mount Google Drive (Optional)
# @markdown 💾 Run this to save all your generated FLUX images directly into your Google Drive.
from google.colab import drive
import os

try:
  drive.mount("/content/drive")
  os.makedirs("/content/drive/MyDrive/FLUX_Images", exist_ok=True)
  print("✅ Google Drive connected! Saved images folder: /content/drive/MyDrive/FLUX_Images")
except Exception as e:
  print("⚠️ Google Drive not mounted (optional step skipped)")

# %%
# @title Install FLUX Dependencies (Diffusers, Transformers, Accelerate, Gradio)
# @markdown ⚙️ Installs the official diffusion stack for FLUX.
import os
import sys
from IPython.display import clear_output

# %cd /content
print("📦 Step 1/3: Cloning FLUX Studio repository...")
if not os.path.exists("/content/ai-faceswapper-pro"):
  # !git clone https://github.com/OddBoyXD/ai-faceswapper-pro.git /content/ai-faceswapper-pro
else:
  # %cd /content/ai-faceswapper-pro
  # !git pull

# %cd /content/ai-faceswapper-pro

print("⚡ Step 2/3: Installing PyTorch & Diffusers stack...")
# !pip install -q --upgrade pip
# !pip install -q diffusers transformers accelerate sentencepiece protobuf torchvision gradio

clear_output()
print("=" * 60)
print("✅ Setup Complete! FLUX Studio is 100% Ready.")
print("👉 Run Step 2 below to launch your FLUX WebUI!")
print("=" * 60)

# %% [markdown]
# ### **2. Launch FLUX WebUI (Click Public Link)**
# Run this cell to start the server and click the public `.gradio.live` link.

# %%
# @title **Launch FLUX.2 / FLUX.1 [dev] WebUI**
from IPython.display import clear_output
import os

# %cd /content/ai-faceswapper-pro

print("🌐 Starting FLUX WebUI...")
# !python flux_dev_studio.py
