# %% [markdown]
# ## **⚡ Fooocus AI Studio • Midjourney Quality & FaceSwap (Kaggle & Colab)**
# Official [Fooocus by lllyasviel](https://github.com/lllyasviel/Fooocus) running on **Kaggle Dual-GPU (30 Hrs/Week Free)** and **Google Colab**!
#
# Midjourney-grade offline image generation • ImagePrompt & FaceSwap • Inpainting & Outpainting • 100+ Visual Art Styles • 100% Free!
#
# [GitHub Repository](https://github.com/OddBoyXD/ai-faceswapper-pro)
#
# <br>
#
# ---
#
# <br>
#
# #### **Highlights & Capabilities**
# * 🎨 **Midjourney-Grade Photorealism**: GPT2 Prompt Expansion with realistic cinematic lighting & textures
# * 📸 **Built-in FaceSwap & ImagePrompt**: Swap faces onto any pose, outfit, or scene with CPDS / PyraCanny
# * 🖌️ **Inpaint & Outpaint**: Erase & replace objects, change clothes, or expand canvas borders
# * 🚀 **Kaggle Dual-GPU Free**: High-speed generation in 4–6 seconds
# * 🌐 **Public Gradio Link**: Access your private Fooocus studio from any PC, Mac, Android, or iOS device

# %% [markdown]
# ### **1. Launch Fooocus Studio (1-Click Execution)**
# Run this cell to setup Fooocus, download checkpoints, and start the WebUI.

# %%
# @title **Launch Fooocus WebUI**
import os
import sys

work_dir = "/kaggle/working" if os.path.exists("/kaggle") else "/content"
# %cd {work_dir}

print("📦 Step 1/2: Cloning Fooocus repository...")
if not os.path.exists(os.path.join(work_dir, "Fooocus")):
  # !git clone https://github.com/lllyasviel/Fooocus.git
else:
  # %cd {os.path.join(work_dir, 'Fooocus')}
  # !git pull

# %cd {os.path.join(work_dir, 'Fooocus')}

print("🌐 Step 2/2: Launching Fooocus Studio with Public Gradio Link...")
# !python entry_with_update.py --share --theme dark --always-high-vram
