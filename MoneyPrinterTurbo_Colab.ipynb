# %% [markdown]
# ## **⚡ MoneyPrinterTurbo & AI YouTube Video Creator**
# The official, all-in-one AI Video Automation Engine featured in the YouTube tutorial: [Watch Tutorial](https://youtu.be/mmYCbuZlHpQ).
#
# Generates **1-Click Full YouTube Shorts, TikToks & Reels**: AI Scriptwriting + Multi-Language Voiceover (Hindi / English) + HD Stock Video / AI Scenes + Dynamic Animated Subtitles + Auto Background Music!
#
# [GitHub Repository](https://github.com/OddBoyXD/ai-faceswapper-pro) — [Tutorial Video](https://youtu.be/mmYCbuZlHpQ)
#
# <br>
#
# ---
#
# <br>
#
# #### **Highlights & Capabilities (Exact Tutorial Match)**
# * 🎬 **Complete 1-Sentence Video Generator**: Type 1 sentence/topic ➔ Generates full 1080p MP4
# * 🎙️ **Multi-Language TTS**: High-definition Hindi (Madhur/Swara), English, Bengali, etc. with natural emotions
# * 🎥 **HD Stock Footage + 4K AI Imagery**: Automatically pairs every sentence with matching cinematic video clips
# * 🔤 **Viral Subtitles (Alex Hormozi / MrBeast Style)**: Word-by-word highlighted animated captions
# * 🎵 **Auto-Ducking Background Music**: Lowers music volume automatically when the narrator speaks
# * 🚀 **Free Google Colab T4 GPU**: Runs 100% free with Streamlit / Gradio WebUI

# %% [markdown]
# ### **1. Install MoneyPrinterTurbo & Video Libraries**
# Run these cells to mount Google Drive (optional) and install the engine.

# %%
# @title Mount Google Drive (Optional)
# @markdown 💾 Run this to mount Google Drive so your finished videos are saved permanently.
from google.colab import drive
import os

try:
  drive.mount("/content/drive")
  os.makedirs("/content/drive/MyDrive/MoneyPrinter_Videos", exist_ok=True)
  print("✅ Google Drive connected! Saved videos folder: /content/drive/MyDrive/MoneyPrinter_Videos")
except Exception as e:
  print("⚠️ Google Drive not mounted (optional step skipped)")

# %%
# @title Setup Environment & Install MoneyPrinterTurbo Engine
# @markdown ⚙️ Clones the engine, installs FFmpeg, ImageMagick, Streamlit, Edge-TTS, and video dependencies.
import os
import sys
from IPython.display import clear_output

# %cd /content
print("📦 Step 1/3: Cloning MoneyPrinterTurbo & Setup Files...")
if not os.path.exists("/content/MoneyPrinterTurbo"):
  # !git clone https://github.com/harry0703/MoneyPrinterTurbo.git /content/MoneyPrinterTurbo
else:
  # %cd /content/MoneyPrinterTurbo
  # !git pull

# %cd /content/MoneyPrinterTurbo

print("⚡ Step 2/3: Installing FFmpeg, ImageMagick & Video packages...")
# !apt-get update -qq && apt-get install -y -qq ffmpeg imagemagick libgl1-mesa-glx fonts-noto-cjk fonts-noto-color-emoji
# !sed -i 's/<policy domain="path" rights="none" pattern="@\*" \/>/<policy domain="path" rights="read | write" pattern="@\*" \/>/' /etc/ImageMagick-6/policy.xml || true

print("📥 Step 3/3: Installing Python Requirements & Localtunnel...")
# !pip install -q --upgrade pip
# !pip install -q -r requirements.txt
# !npm install -g -q localtunnel &> /dev/null

clear_output()
print("=" * 60)
print("✅ Setup Complete! MoneyPrinterTurbo is 100% Ready.")
print("👉 Now run Step 2 below to launch your WebUI!")
print("=" * 60)

# %% [markdown]
# ### **2. Start MoneyPrinterTurbo WebUI (Click Public Link)**
# Run this cell to start the server and click the public web link.

# %%
# @title **Launch MoneyPrinterTurbo WebUI**
from IPython.display import clear_output
import os
import subprocess

# %cd /content/MoneyPrinterTurbo

print("🌐 Starting MoneyPrinterTurbo WebUI...")
print("🔑 Password IP for Localtunnel:", subprocess.check_output('curl -s https://ipv4.icanhazip.com', shell=True).decode().strip())
print("=" * 60)

# Start streamlit with localtunnel
# !streamlit run webui/Main.py --server.port 8501 & lt --port 8501
