# %% [markdown]
# # 🎬 True AI Animated Story Movie Studio (Dual T4 GPU)
# ### 🌟 Continuous 24fps AI Animation Video • Real Character Movement • AnimateDiff & SVD GPU Engine
#
# - 🏃‍♂️ **Real Continuous Motion**: Characters physically walk, turn heads, aim weapons, open doors, and talk.
# - 📖 **100% Verbatim Story Engine**: Zero cuts, complete A-Z textbook/novel chapters.
# - 🎙️ **Kokoro & XTTS-v2 Human Voice Engine**: Natural human breath, emotional tones, and inflection.
# - 🔤 **Dynamic Bouncy Karaoke Subtitles**: Center-aligned, high-contrast, viral readability.
# - 📺 **Full 1080p MP4 Movie Export**.

# %%
# @title 🚀 1. Install GPU Video Diffusion & AnimateDiff Engines (Dual T4 GPU)
# !pip install -q diffusers transformers accelerate moviepy edge-tts pillow numpy soundfile
# !apt-get update -qq && apt-get install -y -qq ffmpeg
import torch
print('✅ GPU Available:', torch.cuda.is_available(), '| Device:', torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'CPU')

# %%
# @title 🎬 2. Clone Repository & Run True AI Animation Movie Studio
import os
if not os.path.exists('/kaggle/working/ai-faceswapper-pro'):
    # !git clone https://github.com/OddBoyXD/ai-faceswapper-pro.git /kaggle/working/ai-faceswapper-pro
else:
    # %cd /kaggle/working/ai-faceswapper-pro
    # !git pull

# %cd /kaggle/working/ai-faceswapper-pro
# !python ai_animated_story_engine.py
