# %% [markdown]
# # 🌟 FLUX.1 [dev] Max • 4K Image Studio (Black Forest Labs)
# Flagship 12B Guidance-Distilled Flow Transformer • Peak Photorealism, Perfect Hands & Typography on Free Google Colab T4 GPU.

# %%
# 1. Step out and clone fresh repository with Auth Token
# %cd /content
# !rm -rf /content/faceswapper
# !git clone https://OddBoyXD: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@github.com/OddBoyXD/ai-faceswapper-pro.git /content/faceswapper
# %cd /content/faceswapper

# 2. Install FLUX [dev] Max Dependencies (Lightweight 6.8GB 4-Bit Model - Starts Fast!)
# !pip install -q diffusers transformers accelerate gradio sentencepiece protobuf torch torchvision bitsandbytes huggingface_hub

# 3. Launch FLUX.1 [dev] Max Studio with Free Public Live Link
# !python flux_max_colab.py
